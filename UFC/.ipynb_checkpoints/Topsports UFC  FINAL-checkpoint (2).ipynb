# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
driver = webdriver.Chrome()
driver.maximize_window()

lst = ['https://www.topsport.com.au/Sport/Mixed_Martial_Arts/UFC/Matches', 'https://www.topsport.com.au/Sport/Mixed_Martial_Arts/UFC_269_-_Main_Card_/Matches', 'https://www.topsport.com.au/Sport/Mixed_Martial_Arts/UFC_270_-_Main_Card/Matches', 'https://www.topsport.com.au/Sport/Mixed_Martial_Arts/UFC_Fight_Night_198_-_Main_Card/Matches', 'https://www.topsport.com.au/Sport/Mixed_Martial_Arts/UFC_Fight_Night_198_-_Preliminary_Card/Matches', 'https://www.topsport.com.au/Sport/Mixed_Martial_Arts/UFC_on_ESPN_31_-_Main_Card/Matches', 'https://www.topsport.com.au/Sport/Mixed_Martial_Arts/UFC_on_ESPN_31_-_Preliminary_Card/Matches']    
def Add_Mar(x):
    driver.find_elements_by_class_name('additMark')[x].click()
    time.sleep(5)

    for i in driver.find_elements_by_class_name('icon-navToggle'):
        if 'Total Rounds' in i.text:
            i.click()
        if 'Round Betting' in i.text:
            i.click()
        if 'Double Chance' in i.text:
            i.click()
        if 'Method of Victory' in i.text:
            i.click()

    time.sleep(1)

    for j in driver.find_elements_by_tag_name('tbody'):
        try:
            if len(j.text) > 100:
                others.append(j.text.split('\n'))
            if 'Rounds' in j.text:
                others.append(j.text.split('\n'))
        except:
            continue

    time.sleep(1)

    return others

for k in lst:
    driver.get(k)
    driver.implicitly_wait(15)
    
    league_name = driver.find_element_by_xpath("//h1[@class='icon icon-MMA']").text
    print(f"____________________________________ {league_name} ________________________________________")
    print("")
    a = 0
    try:
        for i in range(len(driver.find_elements_by_class_name('match'))):
            try:
                match = driver.find_elements_by_class_name('match')[i].text.split('\n')
                Player1, Win1, Player2, Win2 = match[1], match[2], match[3], match[4]
                
                print(f"BET{i+1} ---> Player1: {Player1}, Win: {Win1}, Player2: {Player2}, Win: {Win2}")
                
                if 'Additional Market' in match[-1]:
                    others = []
                    Add_Mar(a)
                    a+=1
                    print(others)

            except:
                a+=1
                continue
        print("-------------------------------------------------------------------------------------------------------")
    except:
        print('URL Denied')
# Out:
# C:\Users\fagho\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:483: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# C:\Users\fagho\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:702: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# ____________________________________ UFC 269 - Main Card ________________________________________
#
# BET1 ---> Player1: Darrick Minner, Win: 2.71, Player2: Ryan Hall, Win: 1.46
# BET2 ---> Player1: Eryk Anders, Win: 2.17, Player2: Andre Muniz, Win: 1.69
# BET3 ---> Player1: Matt Schnell, Win: 3.50, Player2: Alex Perez, Win: 1.30
# BET4 ---> Player1: Miranda Maverick, Win: 1.69, Player2: Erin Blanchfield, Win: 2.16
# BET5 ---> Player1: Priscila Cachoeira, Win: 3.95, Player2: Gillian Robertson, Win: 1.25
# BET6 ---> Player1: Tony Kelley, Win: 2.56, Player2: Randy Costa, Win: 1.51
# BET7 ---> Player1: Jordan Wright, Win: 3.85, Player2: Bruno Silva, Win: 1.26
# BET8 ---> Player1: Augusto Sakai, Win: 1.90, Player2: Tai Tuivasa, Win: 1.90
# BET9 ---> Player1: Pedro Munhoz, Win: 1.80, Player2: Dominick Cruz, Win: 2.00
# BET10 ---> Player1: Dan Ige, Win: 2.64, Player2: Josh Emmett, Win: 1.49
# BET11 ---> Player1: Raulian Paiva, Win: 3.40, Player2: Sean OMalley, Win: 1.32
# BET12 ---> Player1: Kai Kara France, Win: 2.34, Player2: Cody Garbrandt, Win: 1.60
# BET13 ---> Player1: Charles Oliveira, Win: 2.36, Player2: Dustin Poirier, Win: 1.59
# BET14 ---> Player1: Julianna Pena, Win: 6.00, Player2: Amanda Nunes, Win: 1.13
# -------------------------------------------------------------------------------------------------------
# ____________________________________ UFC 270 - Main Card ________________________________________
#
# BET1 ---> Player1: Ciryl Gane, Win: 1.90, Player2: Francis Ngannou, Win: 1.90
# BET2 ---> Player1: Deiveson Figueiredo, Win: 2.46, Player2: Brandon Moreno, Win: 1.55
# -------------------------------------------------------------------------------------------------------
# ____________________________________ Ufc Fight Night 198 - Main Card ________________________________________
#
# BET1 ---> Player1: Darian Weeks, Win: 2.06, Player2: Bryan Barberena, Win: 1.76
# -------------------------------------------------------------------------------------------------------
# ____________________________________ Ufc Fight Night 198 - Preliminary Card ________________________________________
#
# -------------------------------------------------------------------------------------------------------
# ____________________________________ UFC on ESPN 31 - Main Card ________________________________________
#
# BET1 ---> Player1: Cheyanne Buys, Win: 1.56, Player2: Mallory Martin, Win: 2.41
# BET2 ---> Player1: Jared Vanderaa, Win: 2.56, Player2: Azamat Murzakanov, Win: 1.51
# BET3 ---> Player1: William Knight, Win: 2.31, Player2: Alonzo Menifield, Win: 1.61
# BET4 ---> Player1: Chris Curtis, Win: 3.40, Player2: Brendan Allen, Win: 1.31
# BET5 ---> Player1: Jamahal Hill, Win: 2.43, Player2: Jimmy Crute, Win: 1.57
# BET6 ---> Player1: Rafael Fiziev, Win: 1.81, Player2: Brad Riddell, Win: 1.99
# BET7 ---> Player1: Jose Aldo, Win: 2.12, Player2: Rob Font, Win: 1.73
# -------------------------------------------------------------------------------------------------------
# ____________________________________ UFC on ESPN 31 - Preliminary Card ________________________________________
#
# BET1 ---> Player1: Chris Gruetzemacher, Win: 2.00, Player2: Claudio Puelles, Win: 1.81
# BET2 ---> Player1: Jeremiah Wells, Win: 2.42, Player2: Jake Matthews, Win: 1.56
# BET3 ---> Player1: Maki Pitolo, Win: 2.20, Player2: Dusko Todorovic, Win: 1.67
# BET4 ---> Player1: Vince Morales, Win: 2.24, Player2: Louis Smolka, Win: 1.65
# BET5 ---> Player1: Zhalgas Zhumagulov, Win: 3.30, Player2: Manel Kape, Win: 1.33
# BET6 ---> Player1: Mickey Gall, Win: 2.74, Player2: Alex Morono, Win: 1.45
# BET7 ---> Player1: Clay Guida, Win: 2.41, Player2: Leonardo Santos, Win: 1.57
# -------------------------------------------------------------------------------------------------------
