# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
driver = webdriver.Chrome()
driver.get('https://www.unibet.com.au/betting/sports/filter/ufc_mma/ufc/all/matches')
driver.implicitly_wait(30)

driver.find_element_by_id('CybotCookiebotDialogBodyLevelButtonLevelOptinAllowAll').click()

for i in range(len(driver.find_elements_by_class_name('a9753'))):
    try:
        if driver.find_elements_by_class_name('_9873c')[i].text  == '':
            match = driver.find_elements_by_class_name('fa117')[i].text.split('\n')
            Player1, Win1, Player2, Win2 = match[1], match[3], match[2], match[4]
            print(f"BET{i+1} ---> {Player1} vs {Player2} | Win: {Win1}/ Win: {Win2}")
            continue
            
        driver.find_elements_by_class_name('a9753')[i].click()

        WLD = driver.find_element_by_xpath("//li[@class='KambiBC-bet-offer-subcategory KambiBC-bet-offer-subcategory--onecrosstwo']").text.split('\n')
        Player1, Win1, Player2, Win2 = WLD[1], WLD[2], WLD[3], WLD[4]

        try:
            YN = driver.find_element_by_xpath("//li[@class='KambiBC-bet-offer-subcategory KambiBC-bet-offer-subcategory--yesno']").text.split('\n')
            TR = driver.find_element_by_xpath("//li[@class='KambiBC-bet-offer-subcategory KambiBC-bet-offer-subcategory--overunder']").text.split('\n')

            driver.find_elements_by_class_name('KambiBC-bet-offer-category')[1].click()
            lst = driver.find_elements_by_class_name('KambiBC-bet-offer-category')[1].text.split('\n')[22:]
            Method = lst[:len(lst)//2]
            Chance = lst[len(lst)//2:]

            def countList(lst1, lst2):
                return [sub[item] for item in range(len(lst2))
                                  for sub in [lst1, lst2]]

            methods = countList(Method, Chance)

        except:
            YN, TR, Method, Chance = [], [], [], []

        driver.back()
        time.sleep(1)
        
        others = YN + TR + methods
        print(f"BET{i+1} ---> {Player1} vs {Player2} | Win: {Win1}/ Win: {Win2}, {others}")

        print('----------------------------------------------------------------------------------------------------------------')
        print()
    except:
        driver.back()
        print('OK')
# Out:
# C:\Users\fagho\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:702: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# C:\Users\fagho\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:483: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# BET1 ---> Smolka, Louis vs Morales, Vince | Win: 1.64/ Win: 2.25, ['To go the distance', 'Yes', '1.75', 'No', '2.00', 'Total Rounds', 'Over', '2.5', '1.62', 'Under', '2.5', '2.20', 'Smolka, Louis by KO, TKO or DQ', '3.00', 'Smolka, Louis by Submission', '6.00', 'Draw', '5.00', 'Morales, Vince by Decision', '67.00', 'Morales, Vince by KO, TKO or DQ', '3.50', 'Morales, Vince by Submission', '5.50', 'Winner', '15.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET2 ---> Morono, Alex vs Gall, Mickey | Win: 1.44/ Win: 2.80, ['To go the distance', 'Yes', '1.60', 'No', '2.25', 'Total Rounds', 'Over', '2.5', '1.50', 'Under', '2.5', '2.50', 'Morono, Alex by KO, TKO or DQ', '2.00', 'Morono, Alex by Submission', '4.50', 'Draw', '11.00', 'Gall, Mickey by Decision', '61.00', 'Gall, Mickey by KO, TKO or DQ', '5.75', 'Gall, Mickey by Submission', '10.00', 'Winner', '7.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET3 ---> Vanderaa, Jared vs Murzakanov, Azamat | Win: 2.75/ Win: 1.45, ['To go the distance', 'Yes', '2.65', 'No', '1.44', 'Total Rounds', 'Over', '1.5', '1.63', 'Under', '1.5', '2.20', 'Vanderaa, Jared by KO, TKO or DQ', '5.00', 'Vanderaa, Jared by Submission', '6.00', 'Draw', '13.00', 'Murzakanov, Azamat by Decision', '67.00', 'Murzakanov, Azamat by KO, TKO or DQ', '5.00', 'Murzakanov, Azamat by Submission', '2.05', 'Winner', '11.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET4 ---> Puelles, Claudio vs Gruetzemacher, Chris | Win: 1.80/ Win: 2.00, ['To go the distance', 'Yes', '1.62', 'No', '2.20', 'Total Rounds', 'Over', '2.5', '1.55', 'Under', '2.5', '2.35', 'Puelles, Claudio by KO, TKO or DQ', '3.00', 'Puelles, Claudio by Submission', '11.00', 'Draw', '5.50', 'Gruetzemacher, Chris by Decision', '61.00', 'Gruetzemacher, Chris by KO, TKO or DQ', '3.00', 'Gruetzemacher, Chris by Submission', '4.50', 'Winner', '15.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET5 ---> Menifield, Alonzo vs Knight, William | Win: 1.62/ Win: 2.30, ['To go the distance', 'Yes', '2.35', 'No', '1.55', 'Total Rounds', 'Over', '1.5', '1.60', 'Under', '1.5', '2.25', 'Menifield, Alonzo by KO, TKO or DQ', '3.50', 'Menifield, Alonzo by Submission', '3.00', 'Draw', '12.00', 'Knight, William by Decision', '71.00', 'Knight, William by KO, TKO or DQ', '6.00', 'Knight, William by Submission', '3.40', 'Winner', '15.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET6 ---> Martin, Mallory vs Vlismas, Cheyanne | Win: 2.55/ Win: 1.51, ['To go the distance', 'Yes', '1.40', 'No', '2.80', 'Total Rounds', 'Over', '2.5', '1.35', 'Under', '2.5', '3.05', 'Martin, Mallory by KO, TKO or DQ', '3.60', 'Martin, Mallory by Submission', '10.00', 'Draw', '12.00', 'Vlismas, Cheyanne by Decision', '51.00', 'Vlismas, Cheyanne by KO, TKO or DQ', '2.05', 'Vlismas, Cheyanne by Submission', '6.00', 'Winner', '9.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET7 ---> Matthews, Jake vs Wells, Jeremiah | Win: 1.55/ Win: 2.45, ['To go the distance', 'Yes', '1.87', 'No', '1.87', 'Total Rounds', 'Over', '2.5', '1.70', 'Under', '2.5', '2.08', 'Matthews, Jake by KO, TKO or DQ', '2.30', 'Matthews, Jake by Submission', '5.10', 'Draw', '7.00', 'Wells, Jeremiah by Decision', '67.00', 'Wells, Jeremiah by KO, TKO or DQ', '7.00', 'Wells, Jeremiah by Submission', '4.50', 'Winner', '9.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET8 ---> Zhumagulov, Zhalgas vs Kape, Manel | Win: 3.15/ Win: 1.36, ['To go the distance', 'Yes', '1.60', 'No', '2.25', 'Total Rounds', 'Over', '2.5', '1.50', 'Under', '2.5', '2.50', 'Zhumagulov, Zhalgas by KO, TKO or DQ', '4.50', 'Zhumagulov, Zhalgas by Submission', '10.00', 'Draw', '13.00', 'Kape, Manel by Decision', '61.00', 'Kape, Manel by KO, TKO or DQ', '2.20', 'Kape, Manel by Submission', '3.40', 'Winner', '12.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET9 ---> Pitolo, Maki vs Todorovic, Dusko | Win: 2.35/ Win: 1.60, ['To go the distance', 'Yes', '2.30', 'No', '1.57', 'Total Rounds', 'Over', '1.5', '1.50', 'Under', '1.5', '2.50', 'Pitolo, Maki by KO, TKO or DQ', '5.50', 'Pitolo, Maki by Submission', '4.00', 'Draw', '16.00', 'Todorovic, Dusko by Decision', '71.00', 'Todorovic, Dusko by KO, TKO or DQ', '3.50', 'Todorovic, Dusko by Submission', '3.00', 'Winner', '8.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET10 ---> Barberena, Bryan vs Weeks, Darian | Win: 1.80/ Win: 2.00, ['To go the distance', 'Yes', '2.30', 'No', '1.57', 'Total Rounds', 'Over', '2.5', '1.95', 'Under', '2.5', '1.80', 'Barberena, Bryan by KO, TKO or DQ', '4.00', 'Barberena, Bryan by Submission', '3.50', 'Draw', '8.00', 'Weeks, Darian by Decision', '67.00', 'Weeks, Darian by KO, TKO or DQ', '4.50', 'Weeks, Darian by Submission', '4.00', 'Winner', '10.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET11 ---> Allen, Brendan vs Curtis, Chris | Win: 1.28/ Win: 3.70, ['To go the distance', 'Yes', '2.15', 'No', '1.66', 'Total Rounds', 'Over', '2.5', '1.87', 'Under', '2.5', '1.87', 'Allen, Brendan by KO, TKO or DQ', '2.50', 'Allen, Brendan by Submission', '7.50', 'Draw', '2.62', 'Curtis, Chris by Decision', '67.00', 'Curtis, Chris by KO, TKO or DQ', '10.00', 'Curtis, Chris by Submission', '5.50', 'Winner', '26.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET12 ---> Crute, Jim vs Hill, Jamahal | Win: 1.53/ Win: 2.50, ['To go the distance', 'Yes', '3.15', 'No', '1.33', 'Total Rounds', 'Over', '1.5', '1.83', 'Under', '1.5', '1.91', 'Crute, Jim by KO, TKO or DQ', '4.75', 'Crute, Jim by Submission', '3.75', 'Draw', '3.50', 'Hill, Jamahal by Decision', '67.00', 'Hill, Jamahal by KO, TKO or DQ', '8.00', 'Hill, Jamahal by Submission', '3.40', 'Winner', '21.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET13 ---> Guida, Clay vs Santos, Leonardo | Win: 2.50/ Win: 1.53, ['To go the distance', 'Yes', '1.60', 'No', '2.25', 'Total Rounds', 'Over', '2.5', '1.50', 'Under', '2.5', '2.50', 'Guida, Clay by KO, TKO or DQ', '3.40', 'Guida, Clay by Submission', '9.00', 'Draw', '17.00', 'Santos, Leonardo by Decision', '67.00', 'Santos, Leonardo by KO, TKO or DQ', '2.60', 'Santos, Leonardo by Submission', '5.50', 'Winner', '5.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET14 ---> Fiziev, Rafael vs Riddell, Brad | Win: 1.83/ Win: 2.00, ['To go the distance', 'Yes', '1.57', 'No', '2.30', 'Total Rounds', 'Over', '2.5', '1.45', 'Under', '2.5', '2.62', 'Fiziev, Rafael by KO, TKO or DQ', '2.95', 'Fiziev, Rafael by Submission', '4.00', 'Draw', '19.00', 'Riddell, Brad by Decision', '51.00', 'Riddell, Brad by KO, TKO or DQ', '2.95', 'Riddell, Brad by Submission', '5.00', 'Winner', '21.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET15 ---> Font, Rob vs Aldo, Jose | Win: 1.68/ Win: 2.20, ['To go the distance', 'Yes', '1.72', 'No', '2.05', 'Total Rounds', 'Over', '4.5', '1.66', 'Under', '4.5', '2.15', 'Font, Rob by KO, TKO or DQ', '2.95', 'Font, Rob by Submission', '3.50', 'Draw', '15.00', 'Aldo, Jose by Decision', '51.00', 'Aldo, Jose by KO, TKO or DQ', '3.60', 'Aldo, Jose by Submission', '5.00', 'Winner', '17.00']
# ----------------------------------------------------------------------------------------------------------------
#
# BET16 ---> Silva, Bruno vs Wright, Jordan | Win: 1.28/ Win: 3.75
# BET17 ---> Oliveira, Charles vs Poirier, Dustin | Win: 2.35/ Win: 1.61
# BET18 ---> Emmett, Josh vs Ige, Dan | Win: 1.45/ Win: 2.75
# BET19 ---> France, Kai Kara vs Garbrandt, Cody | Win: 2.45/ Win: 1.55
# BET20 ---> Sakai, Augusto vs Tuivasa, Tai | Win: 1.90/ Win: 1.90
# BET21 ---> Nunes, Amanda vs Peña, Julianna | Win: 1.13/ Win: 6.25
# BET22 ---> Paiva, Raulian vs O'Malley, Sean | Win: 3.70/ Win: 1.29
# BET23 ---> Neal, Geoff vs Ponzinibbio, Santiago | Win: 1.90/ Win: 1.90
# BET24 ---> Munhoz, Pedro vs Cruz, Dominick | Win: 1.90/ Win: 1.90
# BET25 ---> Robertson, Gillian vs Cachoeira, Priscila | Win: 1.30/ Win: 3.55
# BET26 ---> Hall, Ryan vs Minner, Darrick | Win: 1.45/ Win: 2.75
# BET27 ---> Perez, Alex vs Schnell, Matt | Win: 1.31/ Win: 3.45
# BET28 ---> Costa, Randy vs Kelley, Tony | Win: 1.50/ Win: 2.60
# BET29 ---> Muniz, Andre vs Anders, Eryk | Win: 1.70/ Win: 2.15
# BET30 ---> Blanchfield, Erin vs Maverick, Miranda | Win: 2.15/ Win: 1.70
# BET31 ---> Elkins, Darren vs Swanson, Cub | Win: 2.65/ Win: 1.47
# BET32 ---> Thompson, Stephen vs Muhammad, Belal | Win: 1.40/ Win: 2.95
# BET33 ---> Ferreira, Diego vs Gamrot, Mateusz | Win: 2.45/ Win: 1.55
# BET34 ---> Lemos, Amanda vs Hill, Angela | Win: 1.29/ Win: 3.60
# BET35 ---> Mayes, Don'Tale vs Parisian, Josh | Win: 1.50/ Win: 2.60
# BET36 ---> Assuncao, Raphael vs Simon, Ricky | Win: 3.05/ Win: 1.38
# BET37 ---> Sayles, Matt vs Leavitt, Jordan | Win: 1.90/ Win: 1.90
# BET38 ---> Pennington, Raquel vs Avila, Julia | Win: 1.73/ Win: 2.10
# BET39 ---> Tafa, Justin vs Hunsucker, Harry | Win: 1.30/ Win: 3.50
# BET40 ---> Eubanks, Sijara vs Gatto, Melissa | Win: 1.44/ Win: 2.80
# BET41 ---> Jourdain, Charles vs Ewell, Andre | Win: 1.50/ Win: 2.60
# BET42 ---> Lewis, Derrick vs Daukaus, Chris | Win: 2.10/ Win: 1.75
# BET43 ---> Meerschaert, Gerald vs Magomedov, Abusupiyan | Win: 2.15/ Win: 1.70
# BET44 ---> Moreno, Brandon vs Figueiredo, Deiveson | Win: 1.60/ Win: 2.38
# BET45 ---> Ngannou, Francis vs Gane, Ciryl | Win: 1.87/ Win: 1.95
