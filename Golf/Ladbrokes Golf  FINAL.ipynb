# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.maximize_window()
driver.get('https://www.ladbrokes.com.au/sports/golf')
driver.implicitly_wait(15)

links = [i.get_attribute('href') for i in driver.find_elements_by_class_name('matches-filter__link')]

for i in links:
    if 'future' in i:
        continue
    driver.get(i)
    driver.implicitly_wait(10)
    name = driver.find_element_by_class_name('page-header-title').text
    print(f'-------------------------------- {name} -------------------------------')
    
    if 'multis' in i:
        for i in range(len(driver.find_elements_by_class_name('sport-event-card'))):
            try:
                match = driver.find_elements_by_class_name('sport-event-card')[i].text.split('\n')
                Player, Top20, Top10, Top5 = match[0], match[4], match[6], match[-1]
                print(f"Player: {Player} --> TOP 20: {Top20}, TOP 10: {Top10}, TOP 5: {Top5}")
            except:
                continue
    else:
        try:
            for a in range(len(driver.find_elements_by_xpath("//div[@class='markets-link-inner']"))):
                driver.implicitly_wait(15)
                if '1 Market' in driver.find_elements_by_xpath("//div[@class='markets-link-inner']")[a].text:
                    match = driver.find_elements_by_xpath("//div[@class='sports-market-primary']")[a].text.split('\n')
                    Player1, Win1, Tie, Player2, Win2 = match[0], match[1], match[3], match[4], match[5]
                    print(f"BET{a+1} ---> Player1: {Player1}, Win: {Win1}, TIE: {Tie}, Player2: {Player2}, Win: {Win2}")
                else:   
                    driver.find_elements_by_xpath("//div[@class='markets-link-inner']")[a].click()
                    time.sleep(5)
                    for j in driver.find_elements_by_xpath("//div[@class='market-group']"):
                        j.click()
                        for i in driver.find_elements_by_xpath("//div[@class='market-two-col']"):
                            i.click()
                    print('-------------------------')

                    lst = driver.find_elements_by_xpath("//div[@class='market-two-col']")
                    match = lst[0].text.split('\n')
                    Player1, Win1, Player2, Win2 = match[1], match[2], match[3], match[4]
                    driver.back()
                    print(f"BET{a+1} ---> Player1: {Player1}, Win: {Win1}, Player2: {Player2}, Win: {Win2}")

        except:
            try:
                for i in range(len(driver.find_elements_by_class_name('market-group'))):
                    if 'NATIONALITY' in driver.find_elements_by_class_name('market-group')[i].text:
                        driver.find_elements_by_class_name('market-group')[i].click()

                for i in range(len(driver.find_elements_by_class_name('market-two-col'))):
                    if 'Top' in driver.find_elements_by_class_name('market-two-col')[i].text:
                        name = driver.find_elements_by_class_name('market-two-col')[i].text
                        print(f'----------------- {name} ---------------------')
                        driver.find_elements_by_class_name('market-two-col')[i].click()
                        lst = driver.find_elements_by_class_name('market-two-col')[i].text.split('\n')
                        del lst[0]
                        Players = []
                        Odds = []
                        for j in range(len(lst)):
                            if j%2 == 0:
                                Players.append(lst[j])
                            else:
                                Odds.append(lst[j])
                        for a in range(len(Players)):
                            print(f'Player : {Players[a]} ---> Odd : {Odds[a]}') 
            except:
                print('URL DENIED')
                continue
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 97.0.4692
# [WDM] - Get LATEST driver version for 97.0.4692
# [WDM] - Driver [C:\Users\fagho\.wdm\drivers\chromedriver\win32\97.0.4692.71\chromedriver.exe] found in cache
# <ipython-input-1-bbc4c8dbd03a>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# C:\Users\fagho\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:702: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# C:\Users\fagho\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:683: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...
