# %%
# from selenium import webdriver
# from webdriver_manager.chrome import ChromeDriverManager
# from selenium.webdriver.common.keys import Keys
# driver = webdriver.Chrome()
# driver.get('https://pointsbet.com.au/sports/golf')
# driver.implicitly_wait(30)

for i in driver.find_elements_by_xpath('//div[@class="fmz4te5"]/button'):
    if 'ALL COMPS' in i.text:
        i.click()
        
links = [i.get_attribute('href') for i in driver.find_elements_by_xpath('//section[@class="fki1lpw"]/div/div/a')]
for i in links:
    if 'Future' in i:
        continue
    driver.get(i)
    driver.implicitly_wait(10)
    name = driver.find_element_by_tag_name('h1').text
    print(f'------------------------------------- {name} ------------------------------------')
    
    if '1 Market' not in driver.find_element_by_class_name('f6rx3n6').text:
        driver.get(driver.find_element_by_xpath("//div[@class='f1oyvxkl']/a").get_attribute('href'))
        driver.implicitly_wait(10)
        print('TOPS')
        continue
    
    try:
        driver.find_element_by_class_name('f1qtqpud').click()
        Players = [i.text.split('\n')[0] for i in driver.find_elements_by_class_name('f1lwbeue')]
        Odds = [i.text.split('\n')[1] for i in driver.find_elements_by_class_name('f1lwbeue')]

        for k in range(len(Players)):
            print(f"{Players[k]} | {Odds[k]}")
    except:
        try:
            for k in range(len(driver.find_elements_by_class_name('f1oyvxkl'))):
                match = driver.find_elements_by_class_name('f1oyvxkl')[k].text.split('\n')
                Player1, Player2, Tie, Win1, Win2 = match[-6], match[-4], match[-1], match[-5], match[-3]
                print(f"{Player1} vs {Player2}, {Tie}, {Win1}/ {Win2}")
        except:
            continue
# Out:
# ------------------------------------- 2021 HERO WORLD CHALLENGE ------------------------------------
# C:\Users\fagho\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:483: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# TOPS
# ------------------------------------- 2021 HERO WORLD CHALLENGE 2/3 BALLS ------------------------------------
# Matthew Fitzpatrick vs Tyrrell Hatton, 8.70, 2.06/ 2.13
# Scottie Scheffler vs Sam Burns, 8.75, 2.08/ 2.11
# Webb Simpson vs Daniel Berger, 8.75, 2.13/ 2.06
# Harris English vs Tony Finau, 8.75, 2.35/ 1.89
# Patrick Reed vs Abraham Ancer, 8.90, 2.23/ 1.96
# Henrik Stenson vs Viktor Hovland, 9.00, 3.15/ 1.56
# Justin Rose vs Xander Schauffele, 8.75, 2.39/ 1.86
# Collin Morikawa vs Rory McIlroy, 8.85, 2.08/ 2.10
# Justin Thomas vs Brooks Koepka, 8.95, 1.83/ 2.43
# ...

# %%
for i in driver.find_elements_by_class_name('f18dqkdv'):
    if 'TOP' in i.text:
        i.click()
# Out:
# C:\Users\fagho\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:702: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
